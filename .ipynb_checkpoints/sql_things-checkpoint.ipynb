# %%
%lsconnect
# Out:
# Disconnected: NAME=AWS_APJ, USER=DBC, HOST=APJ-Demo-Perm-NLB4-04313a2144f2d140.elb.ap-southeast-2.amazonaws.com
# Disconnected: NAME=AWS_PROD, USER=tb250045, HOST=tdprd2.td.teradata.com, PROPS="logmech=LDAP,tmode=TERA,dbs_port=1025"
# Disconnected: NAME=AWS_machine, USER=greig, HOST=13.239.63.137, DATABASE=dbc
# Disconnected: NAME=CSE, USER=demo_user, HOST=demo-03p9jzrz3oc8j7qv.env.clearscape.teradata.com
# Disconnected: NAME=INDBXSP, USER=tb250045, HOST=tdprd2.td.teradata.com, DATABASE=TRNG_XSP, PROPS="tmode=TERA, logmech=LDAP"
# Disconnected: NAME=PROD, USER=tb250045, HOST=tdprd.td.teradata.com, PROPS="logmech=LDAP,tmode=TERA,dbs_port=1025"
# Disconnected: NAME=Transcend-Vantage24-Beta, USER=tb250045, HOST=vantage24.td.teradata.com, PROPS="logMech=LDAP,logmech=LDAP"
# Disconnected: NAME=Vantage-Live, USER=tb250045, HOST=tdprd3.td.teradata.com, DATABASE=tb250045, PROPS="logmech=LDAP"
# Disconnected: NAME=aws_optus, USER=dbc, HOST=141.206.0.153
# Disconnected: NAME=aws_optus_mldb, USER=mldb, HOST=141.206.0.153
# Disconnected: NAME=aws_optus_tat, USER=OPTUSPOC_Tatiana, HOST=141.206.0.153
# Disconnected: NAME=clearscape, USER=demo_user, HOST=demomarch2024-03p9jzrz3oc8j7qv.env.clearscape.teradata.com, PROPS="tmode=TERA,dbs_port=1025"
# Disconnected: NAME=emea_vm, USER=demo_user, HOST=172.16.181.128
# Disconnected: NAME=emea_vm_dbc, USER=dbc, HOST=172.16.181.128, DATABASE=demo_db, PROPS="logmech=LDAP,tmode=TERA,dbs_port=1025"
# Disconnected: NAME=local_17.20, USER=dbc, HOST=127.0.0.1, PROPS="logmech=TD2"
# Disconnected: NAME=training_demo, USER=CLOUD_WS_Imran, HOST=APJ-Demo-Perm-NLB4-04313a2144f2d140.elb.ap-southeast-2.amazonaws.com, DATABASE=CLOUD_WS_WORK_DB

# %%
%rmconnect CSE
# Out:
# Success: connection removed

# %%
%addconnect name=CSE, user=demo_user, host=demo-june-2024-03p9jzrz3oc8j7qv.env.clearscape.teradata.com
# Out:
# Success: 'CSE' connection added

# %%
%connect CSE
# Out:
# Password: ········
# Success: 'CSE' connection established and activated for user 'demo_user'

# %%
sel CAST(CAST(json_report AS JSON).JSONExtractValue('$.cluster') AS INT) as cluster_tb
    ,CAST(CAST(json_report AS JSON).JSONExtractValue('$.affinity(2)') AS INT) as affinity_2
    ,a.* 
from kmens_pmml_result_jsom as a
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory43354"><style>
#       table.tdhistory43354 { display: block !important; min-height: 588px !important; overflow: auto !important; height: 588px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory43354 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory43354:last-child { text-align: left !important; }
#       tbody.tdhistory43354 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory43354 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory43354 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory43354"></th><th class="tdhistory43354">id</th><th class="tdhistory43354">species</th><th class="tdhistory43354">prediction</th><th class="tdhistory43354">json_report</th><th class="tdhistory43354">json_report-1</th></tr></thead><tbody class="tdhistory43354 resultset-body"><tr><th class="tdhistory43354" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory43354">61</td><td class="tdhistory43354">Iris-versicolor</td><td class="tdhistory43354">0</td><td class="tdhistory43354">{"affinity(2)":3.278641110982725,"cluster":"0","affinity(0)":1.5361190743604296,"affinity(1)":2.593760204799203}</td><td class="tdhistory43354">0</td></tr><tr><th class="tdhistory43354" style= "background: rgba(243, 243, 243, 0.75)">2</th><td class="tdhistory43354">101</td><td class="tdhistory43354">Iris-virginica</td><td class="tdhistory43354">2</td><td class="tdhistory43354">{"affinity(2)":0.777318709881154,"cluster":"2","affinity(0)":2.0445799010809695,"affinity(1)":5.230027915795479}</td><td class="tdhistory43354">2</td></tr><tr><th class="tdhistory43354" style= "background: rgba(243, 243, 243, 0.75)">3</th><td class="tdhistory43354">40</td><td class="tdhistory43354">Iris-setosa</td><td class="tdhistory43354">1</td><td class="tdhistory43354">{"affinity(2)":4.966414904970209,"cluster":"1","affinity(0)":3.310927733396673,"affinity(1)":0.11131936040060575}</td><td class="tdhistory43354">1</td></tr><tr><th class="tdhistory43354" style= "background: rgba(243, 243, 243, 0.75)">4</th><td class="tdhistory43354">122</td><td class="tdhistory43354">Iris-virginica</td><td class="tdhistory43354">0</td><td class="tdhistory43354">{"affinity(2)":1.5334903970302305,"cluster":"0","affinity(0)":0.8189197473192523,"affinity(1)":3.9527701678696174}</td><td class="tdhistory43354">0</td></tr><tr><th class="tdhistory43354" style= "background: rgba(243, 243, 243, 0.75)">5</th><td class="tdhistory43354">38</td><td class="tdhistory43354">Iris-setosa</td><td class="tdhistory43354">1</td><td class="tdhistory43354">{"affinity(2)":5.067908647651596,"cluster":"1","affinity(0)":3.3583767014256245,"affinity(1)":0.3665951445395862}</td><td class="tdhistory43354">1</td></tr><tr><th class="tdhistory43354" style= "background: rgba(243, 243, 243, 0.75)">6</th><td class="tdhistory43354">141</td><td class="tdhistory43354">Iris-virginica</td><td class="tdhistory43354">2</td><td class="tdhistory43354">{"affinity(2)":0.38934919774404775,"cluster":"2","affinity(0)":1.7748195376598448,"affinity(1)":4.972483484135467}</td><td class="tdhistory43354">2</td></tr><tr><th class="tdhistory43354" style= "background: rgba(243, 243, 243, 0.75)">7</th><td class="tdhistory43354">80</td><td class="tdhistory43354">Iris-versicolor</td><td class="tdhistory43354">0</td><td class="tdhistory43354">{"affinity(2)":2.7786807088966627,"cluster":"0","affinity(0)":1.0243726030936118,"affinity(1)":2.422311292959681}</td><td class="tdhistory43354">0</td></tr><tr><th class="tdhistory43354" style= "background: rgba(243, 243, 243, 0.75)">8</th><td class="tdhistory43354">19</td><td class="tdhistory43354">Iris-setosa</td><td class="tdhistory43354">1</td><td class="tdhistory43354">{"affinity(2)":4.617929948397902,"cluster":"1","affinity(0)":3.112459436859831,"affinity(1)":0.8284877790287555}</td><td class="tdhistory43354">1</td></tr><tr><th class="tdhistory43354" style= "background: rgba(243, 243, 243, 0.75)">9</th><td class="tdhistory43354">78</td><td class="tdhistory43354">Iris-versicolor</td><td class="tdhistory43354">2</td><td class="tdhistory43354">{"affinity(2)":0.8463625936259216,"cluster":"2","affinity(0)":1.0673983464334125,"affinity(1)":4.203283478424932}</td><td class="tdhistory43354">2</td></tr><tr><th class="tdhistory43354" style= "background: rgba(243, 243, 243, 0.75)">10</th><td class="tdhistory43354">17</td><td class="tdhistory43354">Iris-setosa</td><td class="tdhistory43354">1</td><td class="tdhistory43354" ...
